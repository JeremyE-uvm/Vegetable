# %%
pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.8/739.8 kB 1.4 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 4.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 3.4 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 4.1 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 4.2 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.6.2
#     Uninstalling safetensors-0.6.2:
#       Successfully uninstalled safetensors-0.6.2
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.10.3
#     Uninstalling regex-2023.10.3:
#       Successfully uninstalled regex-2023.10.3
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.2.0
#     Uninstalling hf-xet-1.2.0:
#       Successfully uninstalled hf-xet-1.2.0
#   Attempting uninstall: click
# ...
